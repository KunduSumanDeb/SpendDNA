# %% [markdown]
# # Function 02 : Data Cleaning & Standardization
#
# ## Objective
#
# This notebook performs all preprocessing and standardization required before feature engineering.
#
# The notebook is responsible for:
#
# - Loading the validated raw dataset
# - Removing duplicate transactions
# - Cleaning missing values
# - Standardizing dates
# - Standardizing transaction types
# - Cleaning transaction amounts
# - Standardizing payment modes
# - Performing validation checks
# - Exporting the cleaned dataset
#
# This notebook follows the project architecture described in the development document and produces the cleaned dataset for downstream processing.

# %%
# Setup

import os
import sys

PROJECT_ROOT = os.path.abspath("..")

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %%
# Imports

import warnings
import pickle

import numpy as np
import pandas as pd

from Config.paths import *
from Utils.io import *
from Utils.validation import *

warnings.filterwarnings("ignore")

# %%
# Load Dataset

raw_data = load_pickle(RAW_DATA_PKL)

print("Dataset Loaded Successfully")
print(f"Rows    : {raw_data.shape[0]}")
print(f"Columns : {raw_data.shape[1]}")

display(raw_data.head())
# Out:
# Dataset Loaded Successfully
# Rows    : 1328
# Columns : 8
#           Date   Time                       Description   Type  Amount  \
# 0   2024-01-01  03:11                AMAZON SELLER SVCS  Debit   ₹2462
# 1    01-Jan-24  05:44                         BHIM-BMTC     DR   50.00
# 2    01-Jan-24  09:35  NEFT-TECHCRUSH LABS-SALARY MAY24     CR  ₹84728
# 3   2024-01-01  14:07              UPI-AMAN-8934@OKAXIS  Debit   ₹1828
# 4  01 Jan 2024  14:23                      BHIM-BLINKIT  Debit  270.00
#
#     Balance  Mode        Ref
# 0  678275.0   UPI  TXN190872
# 1  681007.0   UPI  TXN143064
# 2  484728.0  NEFT  TXN246316
# 3 -748745.0   UPI  TXN569226
# 4  680737.0   UPI  TXN968962

# %%
# Initial Validation

validate_dataframe(raw_data)
# Out:
# Validation Summary
# ----------------------------------------
# Rows                : 1328
# Columns             : 8
# Missing Values      : 0
# Duplicate Rows      : 18
# {'rows': 1328,
#  'columns': 8,
#  'missing_values': np.int64(0),
#  'duplicate_rows': np.int64(18)}

# %%
# Execute Cleaning

from Utils.cleaning import clean_dataframe

cleaned_data = clean_dataframe(raw_data)

print("Data Cleaning Completed Successfully")

display(cleaned_data.head())
# Out:
# Data Cleaning Completed Successfully
#          Date   Time                       Description    Type   Amount  \
# 0  2024-01-01  03:11                AMAZON SELLER SVCS   Debit   2462.0
# 1  2024-01-01  05:44                         BHIM-BMTC   Debit     50.0
# 2  2024-01-01  09:35  NEFT-TECHCRUSH LABS-SALARY MAY24  Credit  84728.0
# 3  2024-01-01  14:07              UPI-AMAN-8934@OKAXIS   Debit   1828.0
# 4  2024-01-01  14:23                      BHIM-BLINKIT   Debit    270.0
#
#     Balance  Mode        Ref
# 0  678275.0   UPI  TXN190872
# 1  681007.0   UPI  TXN143064
# 2  484728.0  NEFT  TXN246316
# 3 -748745.0   UPI  TXN569226
# 4  680737.0   UPI  TXN968962

# %%
# Final Validation

validate_dataframe(cleaned_data)

print(cleaned_data.info())
# Out:
# Validation Summary
# ----------------------------------------
# Rows                : 1310
# Columns             : 8
# Missing Values      : 0
# Duplicate Rows      : 0
# <class 'pandas.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         1310 non-null   str
#  1   Time         1310 non-null   str
#  2   Description  1310 non-null   str
#  3   Type         1310 non-null   str
#  4   Amount       1310 non-null   float64
#  5   Balance      1310 non-null   float64
#  6   Mode         1310 non-null   str
#  7   Ref          1310 non-null   str
# dtypes: float64(2), str(6)
# memory usage: 145.8 KB
# None

# %%
# Export

save_pickle(cleaned_data, CLEANED_DATA_PKL)

print(f"Cleaned dataset exported to:\n{CLEANED_DATA_PKL}")
# Out:
# Cleaned dataset exported to:
# D:\Projects\SpendDNA\Data\cleaned_data.pkl

# %%
print("=" * 50)
print("Notebook 02 - Data Cleaning Completed")
print("=" * 50)

print(f"Input File          : {RAW_DATA_PKL}")
print(f"Output File         : {CLEANED_DATA_PKL}")

print(f"Input Rows          : {len(raw_data)}")
print(f"Output Rows         : {len(cleaned_data)}")
print(f"Duplicates Removed  : {len(raw_data) - len(cleaned_data)}")

print(f"Columns             : {cleaned_data.shape[1]}")
# Out:
# ...
# Notebook 02 - Data Cleaning Completed
# ...
# Input File          : D:\Projects\SpendDNA\Data\raw_data.pkl
# Output File         : D:\Projects\SpendDNA\Data\cleaned_data.pkl
# Input Rows          : 1328
# Output Rows         : 1310
# Duplicates Removed  : 18
# Columns             : 8
